# %% [markdown]
# ### What is Pandas ?

# %% [markdown]
# Pandas is a fast,powerful,flexible and easy to use open source data analysis and manipulation tool,built on top of the python programming language

# %% [markdown]
# ### Pandas Series

# %% [markdown]
# A Pandas Series is like a column in a table. It is a 1-D array holding data of any type

# %% [markdown]
# ### Importing Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Series from lists

# %%
# string

country = ["India","Pakistan","USA","Nepal","Srilanka"]

pd.Series(country)
# Out:
# 0       India
# 1    Pakistan
# 2         USA
# 3       Nepal
# 4    Srilanka
# dtype: str

# %%
# integers

runs = [11,22,3,34]
pd.Series(runs)
# Out:
# 0    11
# 1    22
# 2     3
# 3    34
# dtype: int64

# %%
# custom index 

marks = [43,22,33,43]
subjects = ["maths","eng","ss","science"]

pd.Series(marks,index = subjects)
# Out:
# maths      43
# eng        22
# ss         33
# science    43
# dtype: int64

# %%
# setting a name 

marks = pd.Series(marks,index = subjects,name="Nitish ke marks")
marks = marks.squeeze()
type(marks)
# Out:
# pandas.Series

# %% [markdown]
# ### Series from dict

# %%
marks = {
    "maths" : 65,
    "ss" : 54,
    "eng" : 32
}

marks_series = pd.Series(marks,name="nitish ke marks")
marks_series = marks_series.squeeze()
marks_series
# Out:
# pandas.Series

# %% [markdown]
# ### Series Attributes

# %%
# size - It tells the numbers of items in series

marks_series.size
# Out:
# 3

# %%
# dtype 

marks_series.dtype
# Out:
# dtype('int64')

# %%
# name

marks_series.name
# Out:
# 'nitish ke marks'

# %%
# is_unique - wheter all items in series is unique or not 

marks_series.is_unique

pd.Series([1,2,3,4,4]).is_unique
# Out:
# False

# %%
# index

marks_series.index
# Out:
# Index(['maths', 'ss', 'eng'], dtype='str')

# %%
# values

marks_series.values
# Out:
# array([65, 54, 32])

# %% [markdown]
# ### Series using read_csv (csv - comma seperated value)

# %%
# with one col


subs = pd.read_csv(r"C:\Users\shiv1\Desktop\Campus-X\Pandas\subs.csv")
subs = subs.squeeze()
subs

# This tell type of csv 
# type(pd.read_csv(r"C:\Users\shiv1\Desktop\Campus-X\Pandas\subs.csv"))
# Out:
# 0       48
# 1       57
# 2       40
# 3       43
# 4       44
#       ...
# 360    231
# 361    226
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# with 2 col

# index_col : tells which column will become index  

vk = pd.read_csv(r"C:\Users\shiv1\Desktop\Campus-X\Pandas\kohli_ipl.csv",index_col="match_no")
vk = vk.squeeze()
vk
# Out:
# match_no
# 1       1
# 2      23
# 3      13
# 4      12
# 5       1
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
movies = pd.read_csv(r"C:\Users\shiv1\Desktop\Campus-X\Pandas\bollywood.csv",index_col="movie")
movies = movies.squeeze()
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ### Series methods

# %%
# head and tail

# head : It will give top 5 rows 

subs.head()
# Out:
#    Subscribers gained
# 0                  48
# 1                  57
# 2                  40
# 3                  43
# 4                  44

# %%
vk.head(3)  # This give custom top 3 rows
# Out:
#           runs
# match_no
# 1            1
# 2           23
# 3           13

# %%
vk.tail()  # This gives last 5 rows 

vk.tail(3)
# Out:
#           runs
# match_no
# 213         73
# 214         25
# 215          7

# %%
# sample : It gives randomly one row 

movies.sample()

movies.sample(5) # This gives randomly 5 rows
# Out:
#                               lead
# movie
# Khosla Ka Ghosla       Anupam Kher
# Riyasat (film)       Rajesh Khanna
# The Silent Heroes       Mann Bagga
# B.A. Pass             Shadab Kamal
# A Flat (film)      Jimmy Sheirgill

# %%
# value_counts : It gives the frequency count of value in dataset

movies.value_counts()
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
#                     ..
# Tanishaa Mukerji     1
# Tanuja               1
# Ankit                1
# Rakhee Gulzar        1
# Edwin Fernandes      1
# Name: count, Length: 566, dtype: int64

# %%
# sort_values : It is use to sort data 

vk.sort_values(by="runs") # ascending order

vk.sort_values(by="runs",ascending=False) # descending order

vk.sort_values(by="runs",ascending=False).head(1) # This gives top runs 

vk.sort_values(by="runs",ascending=False).head(1).values[0] # This gives on run number

# All this changes are not made in the real dataset
# Out:
# array([113])

# %%
# Changes can be made in real dataset 

vk.sort_values(inplace=True,by="runs") # This made permanent change

# %%
vk
# Out:
#           runs
# match_no
# 8            0
# 87           0
# 93           0
# 91           0
# 206          0
# ...        ...
# 164        100
# 120        100
# 123        108
# 126        109
# 128        113
#
# [215 rows x 1 columns]

# %%
# sort_index

movies.sort_index()  # This sorts the movies in aplhabatic order

movies.sort_index(by="movie",inplace=True) # This makes permanent changes
# Out:
#                                         lead
# movie
# 1920 (film)                 Rajniesh Duggall
# 1920: London                   Sharman Joshi
# 1920: The Evil Returns           Vicky Ahuja
# 1971 (2007 film)              Manoj Bajpayee
# 2 States (2014 film)            Arjun Kapoor
# ...                                      ...
# Zindagi 50-50                    Veena Malik
# Zindagi Na Milegi Dobara      Hrithik Roshan
# Zindagi Tere Naam         Mithun Chakraborty
# Zokkomon                     Darsheel Safary
# Zor Lagaa Ke...Haiya!          Meghan Jadhav
#
# [1500 rows x 1 columns]

# %% [markdown]
# ### Series Maths Methods

# %%
# count : It gives total number of items in series,It does not count missing values
# size : Size does count missing value

vk.count()
# Out:
# runs    215
# dtype: int64

# %%
# sum : It gives total

subs.sum()

subs.product() # It gives product *
# Out:
# Subscribers gained    0
# dtype: int64

# %%
# mean -> median -> mode -> Standard deviation  -> Variance

subs.mean()
vk.median()
movies.mode()
subs.std()
vk.var()
# Out:
# runs    688.002478
# dtype: float64

# %%
# min/max

subs.max()
subs.min()
# Out:
# Subscribers gained    33
# dtype: int64

# %%
# describe : It gives a summary of mathematical values 

vk.describe()
# Out:
#              runs
# count  215.000000
# mean    30.855814
# std     26.229801
# min      0.000000
# 25%      9.000000
# 50%     24.000000
# 75%     48.000000
# max    113.000000

# %% [markdown]
# ### Series Indexing

# %%
# integer indexing

x = pd.Series([12,13,14,35,46,57,58,79,9])

print(x[0])
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# dtype: int64
# 12

# %%
# negative indexing

x[-1]    # Series works on positive indexing not on negative indexing
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\shiv1\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\indexes\range.py:521, in RangeIndex.get_loc(self, key)
#     520 try:
# --> 521     return self._range.index(new_key)
#     522 except ValueError as err:
#
# ValueError: range.index(x): x not in range
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[73], line 3
#       1 # negative indexing
#       2
# ----> 3 x[-1]
#
# File c:\Users\shiv1\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
# ...

# %%
type(movies)
movies[0]  # This will not work for dataframe but for series it will work
# Out:
# pandas.Series

# %%
# slicing

print(x[0:5])
# Out:
# 0    12
# 1    13
# 2    14
# 3    35
# 4    46
# dtype: int64

# %%
# negative slicing

movies[-5:]
# Out:
#                                     lead
# movie
# Hum Tumhare Hain Sanam    Shah Rukh Khan
# Aankhen (2002 film)     Amitabh Bachchan
# Saathiya (film)             Vivek Oberoi
# Company (film)                Ajay Devgn
# Awara Paagal Deewana        Akshay Kumar

# %%
# fancy indexing

print(x[[1,3,4,5]])  # For series this is use 
vk[[1,3,4,5]]  # For dataframe this is use
# Out:
# 1    13
# 3    35
# 4    46
# 5    57
# dtype: int64
# match_no
# 1     1
# 3    13
# 4    12
# 5     1
# Name: runs, dtype: int64

# %%
# indexing with labels -> fancy indexing

# %% [markdown]
# ### Editing Series

# %%
# using indexing

# iloc is use for dataframe and no iloc is use in series

marks_series[2] = 100
marks_series
# Out:
# maths     65
# ss        54
# eng       32
# 2        100
# Name: nitish ke marks, dtype: int64

# %%
# What if an index does not exist

marks_series["sci"] = 100
marks_series
# Out:
# maths    100
# ss        54
# eng       32
# 1        100
# sci      100
# Name: nitish ke marks, dtype: int64

# %%
# slicing

marks_series[0:5] = [100,100,100,100]
marks_series
# Out:
# maths    100
# ss       100
# eng      100
# 2        100
# Name: nitish ke marks, dtype: int64

# %%
# fancy indexing

vk.iloc[[0,3,4]] = [0,0,0]
vk
# Out:
# match_no
# 1       0
# 2      23
# 3      13
# 4       0
# 5       0
#        ..
# 211     0
# 212    20
# 213    73
# 214    25
# 215     7
# Name: runs, Length: 215, dtype: int64

# %%
# using index label

movies["Why Cheat India"] = 'shahrukh'
movies
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                                 shahrukh
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Hum Tumhare Hain Sanam                    Shah Rukh Khan
# Aankhen (2002 film)                     Amitabh Bachchan
# Saathiya (film)                             Vivek Oberoi
# Company (film)                                Ajay Devgn
# Awara Paagal Deewana                        Akshay Kumar
# Name: lead, Length: 1500, dtype: str

# %% [markdown]
# ### Copy and Views

# %% [markdown]
# ### Series with Python Functionalities

# %%
# len/type/dir/sorted/max/min

print(len(subs))
print(type(subs))
print(dir(subs))
print(sorted(subs))
print(max(subs))
print(min(subs))
# Out:
# 365
# <class 'pandas.Series'>
# ...

# %%
# type conversion

list(marks_series)
dict(marks_series)
# Out:
# {'maths': np.int64(100),
#  'ss': np.int64(100),
#  'eng': np.int64(100),
#  2: np.int64(100)}

# %%
# membership operator

# It work on index and not on value, it will search in index

'Uri: The Surgical Strike' in movies
# Out:
# True

# %%
# to search in values

"Alia Bhatt" in movies.values
# Out:
# True

# %%
# looping

for i in movies:  # This work on values 
    print(i)

for j in movies.index:  # This works on index 
    print(j)
# Out:
# Uri: The Surgical Strike
# Battalion 609
# The Accidental Prime Minister (film)
# Why Cheat India
# Evening Shadows
# Soni (film)
# Fraud Saiyaan
# Bombairiya
# Manikarnika: The Queen of Jhansi
# Thackeray (film)
# Amavas
# Gully Boy
# Hum Chaar
# Total Dhamaal
# Sonchiriya
# Badla (2019 film)
# Mard Ko Dard Nahi Hota
# Hamid (film)
# Photograph (film)
# Risknamaa
# Mere Pyare Prime Minister
# 22 Yards
# Kesari (film)
# Notebook (2019 film)
# Junglee (2019 film)
# Gone Kesh
# Albert Pinto Ko Gussa Kyun Aata Hai?
# The Tashkent Files
# Kalank
# Setters (film)
# Student of the Year 2
# PM Narendra Modi
# De De Pyaar De
# India's Most Wanted (film)
# Yeh Hai India
# Khamoshi (2019 film)
# Kabir Singh
# Article 15 (film)
# One Day: Justice Delivered
# Hume Tumse Pyaar Kitna
# Super 30 (film)
# Family of Thakurganj
# Batla House
# Jhootha Kahin Ka
# Judgementall Hai Kya
# Chicken Curry Law
# Arjun Patiala
# Jabariya Jodi
# Pranaam
# The Sky Is Pink
# Mission Mangal
# Saaho
# ...

# %%
# Arithmetic Operators(Broadcasting)

100 - marks_series 
100 + marks_series
# Out:
# maths    200
# ss       200
# eng      200
# 2        200
# Name: nitish ke marks, dtype: int64

# %%
# Relational Operators 

vk >= 50
# Out:
# match_no
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
#        ...
# 211    False
# 212    False
# 213     True
# 214    False
# 215    False
# Name: runs, Length: 215, dtype: bool

# %% [markdown]
# ### Boolean Indexing on Series

# %%
# Find no of 50's and 100's scored by kohli

vk[vk >= 50].size
# Out:
# 50

# %%
# Find number of ducks

vk[vk == 0].size
# Out:
# 12

# %%
# Count number of day when i had more than 200 subs a day

subs[subs > 200].size
# Out:
# 59

# %%
# Find actors who have done more than 20 movies

num_movies = movies.value_counts()
num_movies[num_movies > 20]
# Out:
# lead
# Akshay Kumar        48
# Amitabh Bachchan    45
# Ajay Devgn          38
# Salman Khan         31
# Sanjay Dutt         26
# Shah Rukh Khan      22
# Name: count, dtype: int64

# %% [markdown]
# ### Plotting Graphs on Series

# %%
subs.plot()
# Out:
# <Axes: >

# %%
#movies.value_counts().head(20).plot(kind ="bar")
movies.value_counts().head(20).plot(kind ="pie")
# Out:
# <Axes: >

# %% [markdown]
# ### Some important Series methods

# %%
# astype

# between

# clip

# drop_duplicates

# isnull

# dropna

# fillna

# isin

# apply

# copy

# %%
import numpy as np
import pandas as pd

# %%
subs = pd.read_csv(r"C:\Users\shiv1\Desktop\Campus-X\Pandas\subs.csv")
subs
# Out:
#      Subscribers gained
# 0                    48
# 1                    57
# 2                    40
# 3                    43
# 4                    44
# ..                  ...
# 360                 231
# 361                 226
# 362                 155
# 363                 144
# 364                 172
#
# [365 rows x 1 columns]

# %%
vk = pd.read_csv(r"C:\Users\shiv1\Desktop\Campus-X\Pandas\kohli_ipl.csv")
vk = vk.squeeze()

# %%
movies = pd.read_csv(r"C:\Users\shiv1\Desktop\Campus-X\Pandas\bollywood.csv")
movies
# Out:
#                                      movie              lead
# 0                 Uri: The Surgical Strike     Vicky Kaushal
# 1                            Battalion 609       Vicky Ahuja
# 2     The Accidental Prime Minister (film)       Anupam Kher
# 3                          Why Cheat India     Emraan Hashmi
# 4                          Evening Shadows  Mona Ambegaonkar
# ...                                    ...               ...
# 1495                Hum Tumhare Hain Sanam    Shah Rukh Khan
# 1496                   Aankhen (2002 film)  Amitabh Bachchan
# 1497                       Saathiya (film)      Vivek Oberoi
# 1498                        Company (film)        Ajay Devgn
# 1499                  Awara Paagal Deewana      Akshay Kumar
#
# [1500 rows x 2 columns]

# %%
# astype : It changes the type of data 

import sys
sys.getsizeof(vk)
# Out:
# 3604

# %%
sys.getsizeof(vk.astype("int16"))
# Out:
# 1024

# %%
# between

vk[vk.between(51,99)]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 3
#       1 # between
#       2
# ----> 3 vk[vk.between(51,99)]
#
# File c:\Users\shiv1\AppData\Local\Programs\Python\Python314\Lib\site-packages\pandas\core\generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'between'

# %%
# clip : It clip on a given data, means all value will become in a specific range 

subs.clip(100,200)
# Out:
# 0      100
# 1      100
# 2      100
# 3      100
# 4      100
#       ...
# 360    200
# 361    200
# 362    155
# 363    144
# 364    172
# Name: Subscribers gained, Length: 365, dtype: int64

# %%
# drop_duplicates

temp = pd.Series([1,1,1,2,2,3,3,3,4,4])
temp.drop_duplicates()
# Out:
# 0    1
# 3    2
# 5    3
# 8    4
# dtype: int64

# %%
temp.drop_duplicates(keep="last") # This delete the first duplicate item and keep
                                # the last by default it is set to first
# Out:
# 2    1
# 4    2
# 7    3
# 9    4
# dtype: int64

# %%
movies.drop_duplicates()
# Out:
# movie
# Uri: The Surgical Strike                   Vicky Kaushal
# Battalion 609                                Vicky Ahuja
# The Accidental Prime Minister (film)         Anupam Kher
# Why Cheat India                            Emraan Hashmi
# Evening Shadows                         Mona Ambegaonkar
#                                               ...
# Sssshhh...                              Tanishaa Mukerji
# Rules: Pyaar Ka Superhit Formula                  Tanuja
# Right Here Right Now (film)                        Ankit
# Talaash: The Hunt Begins...                Rakhee Gulzar
# The Pink Mirror                          Edwin Fernandes
# Name: lead, Length: 566, dtype: str

# %%
temp.duplicated() # This tells if a value is duplicated or not 

temp.duplicated().sum()  # This tells the sum of duplicated values
# Out:
# np.int64(6)

# %%
vk.duplicated().sum()
# Out:
# np.int64(0)

# %%
temp = pd.Series([1,2,3,np.nan,5,6,np.nan,8,np.nan,10])
temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     NaN
# 4     5.0
# 5     6.0
# 6     NaN
# 7     8.0
# 8     NaN
# 9    10.0
# dtype: float64

# %%
temp.count()
# Out:
# np.int64(7)

# %%
temp.size
# Out:
# 10

# %%
# isnull : It checks if each value is null or not 

temp.isnull().sum()
# Out:
# np.int64(3)

# %%
# dropna  : It drops all null values 

temp.dropna()
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 4     5.0
# 5     6.0
# 7     8.0
# 9    10.0
# dtype: float64

# %%
# fillna : It fills all the missing values 

temp.fillna(0)
temp.fillna(2)
temp.fillna(temp.mean()) # This fills all the missing values with mean of temp
# Out:
# 0     1.0
# 1     2.0
# 2     3.0
# 3     5.0
# 4     5.0
# 5     6.0
# 6     5.0
# 7     8.0
# 8     5.0
# 9    10.0
# dtype: float64

# %%
# isin

vk[vk.isin([49,99])]
# Out:
#      match_no  runs
# 0         NaN   NaN
# 1         NaN   NaN
# 2         NaN   NaN
# 3         NaN   NaN
# 4         NaN   NaN
# ..        ...   ...
# 210       NaN   NaN
# 211       NaN   NaN
# 212       NaN   NaN
# 213       NaN   NaN
# 214       NaN   NaN
#
# [215 rows x 2 columns]

# %%
# apply : It helps in applying a custom logic on series 

movies.apply(lambda x:x.split()[0].upper())
# Out:
# movie
# Uri: The Surgical Strike                  VICKY
# Battalion 609                             VICKY
# The Accidental Prime Minister (film)     ANUPAM
# Why Cheat India                          EMRAAN
# Evening Shadows                            MONA
#                                          ...
# Hum Tumhare Hain Sanam                     SHAH
# Aankhen (2002 film)                     AMITABH
# Saathiya (film)                           VIVEK
# Company (film)                             AJAY
# Awara Paagal Deewana                     AKSHAY
# Name: lead, Length: 1500, dtype: str

# %%
subs.apply(lambda x: "good day" if x> subs.mean() else "bad day")
# Out:
# 0       bad day
# 1       bad day
# 2       bad day
# 3       bad day
# 4       bad day
#          ...
# 360    good day
# 361    good day
# 362    good day
# 363    good day
# 364    good day
# Name: Subscribers gained, Length: 365, dtype: str

# %%
# copy : It creates a copy of data 

new = vk.head().copy()
new
# Out:
#    match_no  runs
# 0         1     1
# 1         2    23
# 2         3    13
# 3         4    12
# 4         5     1

# %%
new[1] = 100
new
# Out:
#    match_no  runs    1
# 0         1     1  100
# 1         2    23  100
# 2         3    13  100
# 3         4    12  100
# 4         5     1  100

# %%
vk
# Out:
#      match_no  runs
# 0           1     1
# 1           2    23
# 2           3    13
# 3           4    12
# 4           5     1
# ..        ...   ...
# 210       211     0
# 211       212    20
# 212       213    73
# 213       214    25
# 214       215     7
#
# [215 rows x 2 columns]
